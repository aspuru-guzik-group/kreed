# %%
import sys
sys.path.append('../')
from src.datamodule import ConformerDatamodule
data = ConformerDatamodule(
    dataset='qm9',
    seed=100,
    batch_size=1,
    split_ratio=(0.8, 0.1, 0.1),
    num_workers=0,
    distributed=False,
    tol=-1.0,
)

dataset = data.datasets['train']
# Out:
# Dataset: 133471 conformations from 133471 molecules.

# %%
import py3Dmol
from src import chem
# i = 70 (train)
# i = 532 (val)
start = 10* 56
import torch
idx = 21153


arrow_len = 6.5
radius = 0.25
mid = 0.9
font_size = 80
M = dataset[idx]
M = M.replace(coords=M.coords * torch.tensor([-1.0, 1.0, 1.0]))
view = py3Dmol.view(width=1500, height=1500)
view.addModel(M.xyzfile(), 'xyz')
view.setStyle({'sphere':{'scale': 0.5}})
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':arrow_len, 'y':0.0, 'z':0.0},
                      'radius': radius,
                      'color':'red',
                      'mid': mid,
                      })
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':0.0, 'y':arrow_len, 'z':0.0},
                      'radius': radius,
                      'color':'green',
                        'mid': mid,
                      })
view.addArrow({
                        'start': {'x':0.0, 'y':0.0, 'z':0.0},
                        'end': {'x':0.0, 'y':0.0, 'z':arrow_len},
                        'radius': radius,
                        'color':'blue',
                        'mid': mid,
                        })
view.addLabel('x', {'position': {'x':arrow_len, 'y':0.3, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'red', 'fontSize': font_size})
view.addLabel('y', {'position': {'x':0.6, 'y':arrow_len, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'green', 'fontSize': font_size})  
view.addLabel('z', {'position': {'x':0.0, 'y':0.15, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':'blue', 'fontSize': font_size})
view.rotate(30, {'x': 1, 'y': -1, 'z': -.2})
view.zoomTo()
view.translate(-80, -50)
view.show()
# Out:
# <div id="3dmolviewer_16881618076566248"  style="position: relative; width: 1500px; height: 1500px">
#         <p id="3dmolwarning_16881618076566248" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16881618076566248 = null;
# var warn = document.getElementById("3dmolwarning_16881618076566248");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16881618076566248 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16881618076566248"),{backgroundColor:"white"});
# viewer_16881618076566248.zoomTo();
# 	viewer_16881618076566248.addModel("18\n\nC -2.719464 -0.656208 0.000734\nH -2.469171 -1.243194 -0.886178\nH -3.781133 -0.415800 -0.000915\nH -2.471256 -1.240146 0.890268\nO -2.043342 0.582218 -0.000553\nC -0.680184 0.501237 -0.000149\nC 0.225850 -0.530600 -0.000160\nC 1.524442 0.047140 0.000102\nC 1.355772 1.405100 0.000272\nN 0.017024 1.672344 -0.000154\nH -0.417812 2.577845 0.001061\nH 2.083865 2.190017 0.000277\nC 2.808300 -0.716633 0.000153\nH 2.887695 -1.349815 0.885554\nH 3.647148 -0.026501 -0.001291\nH 2.886407 -1.352038 -0.883784\nO -0.056852 -1.881886 -0.000358\nH 0.787037 -2.345567 0.000276\n","xyz");
# 	viewer_16881618076566248.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16881618076566248.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 6.5, "y": 0.0, "z": 0.0}, "radius": 0.25, "color": "red", "mid": 0.9});
# 	viewer_16881618076566248.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 6.5, "z": 0.0}, "radius": 0.25, "color": "green", "mid": 0.9});
# 	viewer_16881618076566248.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 6.5}, "radius": 0.25, "color": "blue", "mid": 0.9});
# 	viewer_16881618076566248.addLabel("x",{"position": {"x": 6.5, "y": 0.3, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "red", "fontSize": 80});
# 	viewer_16881618076566248.addLabel("y",{"position": {"x": 0.6, "y": 6.5, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "green", "fontSize": 80});
# 	viewer_16881618076566248.addLabel("z",{"position": {"x": 0.0, "y": 0.15, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "blue", "fontSize": 80});
# 	viewer_16881618076566248.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_16881618076566248.zoomTo();
# 	viewer_16881618076566248.translate(-80,-50);
# viewer_16881618076566248.render();
# });
# </script>

# %%
view.render()

t = view.js()
js = t.startjs + t.endjs

with open("parent.html", "w") as f:
    f.write(js)

# %%
import torch
import torch.linalg as LA
def rotated_to_principal_axes(coords, masses, return_moments=True):
    coords, m = coords.double(), masses.double()

    # Subtract CoM
    com = torch.sum(m * coords, dim=0) / m.sum()
    coords = coords - com

    # Compute planar dyadic
    dyadic = m.unsqueeze(-1) * coords.unsqueeze(-1) * coords.unsqueeze(-2)  # (N 1 1) * (N 3 1) * (N 1 3)
    dyadic = dyadic.sum(dim=0)  # (3 3)

    # Diagonalize in double precision
    moments, V = LA.eigh(dyadic)  # (3) (3 3)

    # Sort eigenvalues in descending order
    moments = torch.flip(moments, dims=[-1])
    V = torch.flip(V, dims=[-1])

    # Sanity check
    Q = V @ torch.diag_embed(moments) @ V.mT
    err = (dyadic - Q).abs().max().item()
    if err > 1e-5:
        print(f"WARNING: numerical instability in diagonalizing planar dyadic (error={err})")

    coords = (coords @ V).float()
    return (coords, (moments.float(), V)) if return_moments else coords

# %%
import py3Dmol
from src import chem

import torch
idx = 21153


example = dataset[idx]
original_coords = example.coords.clone()

atom_idx = 8
new_masses = example.masses.clone()
new_masses[atom_idx] = (13.003355 - 12) * 50 + 12

coords, moments = rotated_to_principal_axes(example.coords, new_masses, return_moments=True)
moments, transform = moments
transform *= torch.tensor([-1.0, 1.0, 1.0]).double()
transform = LA.inv(transform)

back_masses = example.masses.clone()
back_masses[atom_idx] = 12
com = torch.sum(coords * back_masses, dim=0) / back_masses.sum()
com

arrow_len = 6.5
radius = 0.25
# radius = 0.10
# radius = 0.01
mid = 0.9
font_size = 80
M = example.replace(coords=coords)

view = py3Dmol.view(width=1500, height=1500)
view.addModel(M.xyzfile(), 'xyz')
view.setStyle({'sphere':{'scale': 0.5}})
view.setStyle({'index': atom_idx}, {'sphere':{'scale': 0.5, 'color':'yellow'}})



x, y, z = (transform[0] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'red',
  'mid': mid,
  })
x, y, z = (transform[1] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'green',
  'mid': mid,
  })
x, y, z = (transform[2] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'blue',
  'mid': mid,
  })
arr_color = 'yellow'
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':arrow_len, 'y':0.0, 'z':0.0},
                      'radius': radius,
                      'color':arr_color,
                      'mid': mid,
                      })
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':0.0, 'y':arrow_len, 'z':0.0},
                      'radius': radius,
                      'color':arr_color,
                        'mid': mid,
                      })
view.addArrow({
                        'start': {'x':0.0, 'y':0.0, 'z':0.0},
                        'end': {'x':0.0, 'y':0.0, 'z':arrow_len},
                        'radius': radius,
                        'color':arr_color,
                        'mid': mid,
                        })

arr_color = '#8B8000'
view.addLabel('x', {'position': {'x':arrow_len-0.7, 'y':-2.0, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'red', 'fontSize': font_size})
view.addLabel('y', {'position': {'x':1.7, 'y':arrow_len-1.0, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'green', 'fontSize': font_size})  
view.addLabel('z', {'position': {'x':-0.5, 'y':0.0, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':'blue', 'fontSize': font_size})
view.addLabel("x'", {'position': {'x':arrow_len, 'y':0.3, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})
view.addLabel("y'", {'position': {'x':0.5, 'y':arrow_len, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})  
view.addLabel("z'", {'position': {'x':0.0, 'y':0.15, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})
view.rotate(30, {'x': 1, 'y': -1, 'z': -.2})
view.zoomTo()
view.translate(-80, -50)
view.show()
# Out:
# <div id="3dmolviewer_16881618076859515"  style="position: relative; width: 1500px; height: 1500px">
#         <p id="3dmolwarning_16881618076859515" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16881618076859515 = null;
# var warn = document.getElementById("3dmolwarning_16881618076859515");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16881618076859515 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16881618076859515"),{backgroundColor:"white"});
# viewer_16881618076859515.zoomTo();
# 	viewer_16881618076859515.addModel("18\n\nC -3.276435 -0.076350 0.000781\nH -3.213426 -0.711388 -0.886106\nH -4.217402 0.470933 -0.000856\nH -3.214437 -0.707780 0.890341\nO -2.260503 0.902793 -0.000585\nC -0.984142 0.417344 -0.000208\nC -0.428654 -0.838450 -0.000186\nC 0.983351 -0.676069 0.000017\nC 1.229047 0.670088 0.000121\nN 0.031751 1.325943 -0.000290\nH -0.111990 2.320103 0.000888\nH 2.158767 1.200970 0.000069\nC 1.979596 -1.789234 0.000080\nH 1.865780 -2.417099 0.885511\nH 2.986606 -1.381953 -0.001420\nH 1.863820 -2.418910 -0.883827\nO -1.103013 -2.043080 -0.000306\nH -0.436690 -2.738178 0.000333\n","xyz");
# 	viewer_16881618076859515.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16881618076859515.setStyle({"index": 8},{"sphere": {"scale": 0.5, "color": "yellow"}});
# 	viewer_16881618076859515.addArrow({"start": {"x": -0.48525816202163696, "y": -0.26456740498542786, "z": -4.7705976612633094e-05}, "end": {"x": 5.716490922335943, "y": -2.2109250896450137, "z": -0.00028861365532432406}, "radius": 0.25, "color": "red", "mid": 0.9});
# 	viewer_16881618076859515.addArrow({"start": {"x": -0.48525816202163696, "y": -0.26456740498542786, "z": -4.7705976612633094e-05}, "end": {"x": 1.4610995320522262, "y": 5.9371816748120425, "z": 0.00023149053153549953}, "radius": 0.25, "color": "green", "mid": 0.9});
# 	viewer_16881618076859515.addArrow({"start": {"x": -0.48525816202163696, "y": -0.26456740498542786, "z": -4.7705976612633094e-05}, "end": {"x": -0.48511191083615973, "y": -0.2649059279397025, "z": 6.499952283562835}, "radius": 0.25, "color": "blue", "mid": 0.9});
# 	viewer_16881618076859515.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 6.5, "y": 0.0, "z": 0.0}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618076859515.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 6.5, "z": 0.0}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618076859515.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 6.5}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618076859515.addLabel("x",{"position": {"x": 5.8, "y": -2.0, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "red", "fontSize": 80});
# 	viewer_16881618076859515.addLabel("y",{"position": {"x": 1.7, "y": 5.5, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "green", "fontSize": 80});
# 	viewer_16881618076859515.addLabel("z",{"position": {"x": -0.5, "y": 0.0, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "blue", "fontSize": 80});
# 	viewer_16881618076859515.addLabel("x'",{"position": {"x": 6.5, "y": 0.3, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618076859515.addLabel("y'",{"position": {"x": 0.5, "y": 6.5, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618076859515.addLabel("z'",{"position": {"x": 0.0, "y": 0.15, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618076859515.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_16881618076859515.zoomTo();
# 	viewer_16881618076859515.translate(-80,-50);
# viewer_16881618076859515.render();
# });
# </script>

# %%
view.render()

t = view.js()
js = t.startjs + t.endjs

with open("iso1.html", "w") as f:
    f.write(js)

# %%
import py3Dmol
from src import chem

import torch


example = dataset[idx]
original_coords = example.coords.clone()

atom_idx = 0
new_masses = example.masses.clone()
new_masses[atom_idx] = (13.003355 - 12) * 50 + 12

coords, moments = rotated_to_principal_axes(example.coords, new_masses, return_moments=True)
moments, transform = moments
transform *= torch.tensor([-1.0, 1.0, 1.0]).double()
transform = LA.inv(transform)

back_masses = example.masses.clone()
back_masses[atom_idx] = 12
com = torch.sum(coords * back_masses, dim=0) / back_masses.sum()
com

arrow_len = 6.5
radius = 0.25
# radius = 0.10
# radius = 0.01
mid = 0.9
font_size = 80
M = example.replace(coords=coords)

view = py3Dmol.view(width=1500, height=1500)
view.addModel(M.xyzfile(), 'xyz')
view.setStyle({'sphere':{'scale': 0.5}})
view.setStyle({'index': atom_idx}, {'sphere':{'scale': 0.5, 'color':'yellow'}})



x, y, z = (transform[0] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'red',
  'mid': mid,
  })
x, y, z = (transform[1] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'green',
  'mid': mid,
  })
x, y, z = (transform[2] * arrow_len) + com
x = x.item()
y = y.item()
z = z.item()
view.addArrow({
  'start': {'x':com[0].item(), 'y':com[1].item(), 'z':com[2].item()},
  'end': {'x':x, 'y':y, 'z':z},
  'radius': radius,
  'color':'blue',
  'mid': mid,
  })
arr_color = 'yellow'
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':arrow_len, 'y':0.0, 'z':0.0},
                      'radius': radius,
                      'color':arr_color,
                      'mid': mid,
                      })
view.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':0.0, 'y':arrow_len, 'z':0.0},
                      'radius': radius,
                      'color':arr_color,
                        'mid': mid,
                      })
view.addArrow({
                        'start': {'x':0.0, 'y':0.0, 'z':0.0},
                        'end': {'x':0.0, 'y':0.0, 'z':arrow_len},
                        'radius': radius,
                        'color':arr_color,
                        'mid': mid,
                        })

arr_color = '#8B8000'
view.addLabel('x', {'position': {'x':arrow_len-0.7, 'y':-1.0, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'red', 'fontSize': font_size})
view.addLabel('y', {'position': {'x':1.9, 'y':arrow_len-.5, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'green', 'fontSize': font_size})  
view.addLabel('z', {'position': {'x':0.5, 'y':0.0, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':'blue', 'fontSize': font_size})
view.addLabel("x'", {'position': {'x':arrow_len, 'y':0.6, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})
view.addLabel("y'", {'position': {'x':0.5, 'y':arrow_len, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})  
view.addLabel("z'", {'position': {'x':0.0, 'y':0.15, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':arr_color, 'fontSize': font_size})
view.rotate(30, {'x': 1, 'y': -1, 'z': -.2})
view.zoomTo()
view.translate(-80, -50)
view.show()
# Out:
# <div id="3dmolviewer_16881618080471091"  style="position: relative; width: 1500px; height: 1500px">
#         <p id="3dmolwarning_16881618080471091" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16881618080471091 = null;
# var warn = document.getElementById("3dmolwarning_16881618080471091");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16881618080471091 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16881618080471091"),{backgroundColor:"white"});
# viewer_16881618080471091.zoomTo();
# 	viewer_16881618080471091.addModel("18\n\nC -1.995922 -0.197197 0.000288\nH -1.828835 -0.813044 -0.886630\nH -3.014313 0.187272 -0.001460\nH -1.830683 -0.809814 0.889816\nO -1.155533 0.936200 -0.000853\nC 0.183446 0.668075 -0.000307\nC 0.938588 -0.478811 -0.000281\nC 2.304425 -0.085602 0.000155\nC 2.324566 1.282645 0.000386\nN 1.035440 1.731888 -0.000169\nH 0.729582 2.688688 0.001052\nH 3.153911 1.959697 0.000515\nC 3.470737 -1.019068 0.000300\nH 3.461985 -1.657187 0.885672\nH 4.396714 -0.451163 -0.001014\nH 3.460606 -1.659136 -0.883666\nO 0.472305 -1.778224 -0.000587\nH 1.244217 -2.353811 0.000111\n","xyz");
# 	viewer_16881618080471091.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16881618080471091.setStyle({"index": 0},{"sphere": {"scale": 0.5, "color": "yellow"}});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.7880393266677856, "y": 0.0778580904006958, "z": -0.00011390270083211362}, "end": {"x": 7.225981050263273, "y": -0.8181920239483987, "z": 0.0006318608819002291}, "radius": 0.25, "color": "red", "mid": 0.9});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.7880393266677856, "y": 0.0778580904006958, "z": -0.00011390270083211362}, "end": {"x": 1.6840894776119408, "y": 6.515799846124463, "z": -0.00039121352434180073}, "radius": 0.25, "color": "green", "mid": 0.9});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.7880393266677856, "y": 0.0778580904006958, "z": -0.00011390270083211362}, "end": {"x": 0.7873389115733157, "y": 0.07823556001484251, "z": 6.499886048601891}, "radius": 0.25, "color": "blue", "mid": 0.9});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 6.5, "y": 0.0, "z": 0.0}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 6.5, "z": 0.0}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618080471091.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 6.5}, "radius": 0.25, "color": "yellow", "mid": 0.9});
# 	viewer_16881618080471091.addLabel("x",{"position": {"x": 5.8, "y": -1.0, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "red", "fontSize": 80});
# 	viewer_16881618080471091.addLabel("y",{"position": {"x": 1.9, "y": 6.0, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "green", "fontSize": 80});
# 	viewer_16881618080471091.addLabel("z",{"position": {"x": 0.5, "y": 0.0, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "blue", "fontSize": 80});
# 	viewer_16881618080471091.addLabel("x'",{"position": {"x": 6.5, "y": 0.6, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618080471091.addLabel("y'",{"position": {"x": 0.5, "y": 6.5, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618080471091.addLabel("z'",{"position": {"x": 0.0, "y": 0.15, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "#8B8000", "fontSize": 80});
# 	viewer_16881618080471091.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_16881618080471091.zoomTo();
# 	viewer_16881618080471091.translate(-80,-50);
# viewer_16881618080471091.render();
# });
# </script>

# %%
view.render()

t = view.js()
js = t.startjs + t.endjs

with open("iso2.html", "w") as f:
    f.write(js)

# %%
from src.diffusion.lit import LitEquivariantDDPM
from src.experimental.train import TrainEquivariantDDPMConfig # necessary

model = LitEquivariantDDPM.load_from_checkpoint('../final_checkpoints/qm9_p10.ckpt').to('cuda:0')
model
# Out:
# /home/austin/mambaforge/envs/egnn/lib/python3.9/site-packages/pytorch_lightning/utilities/migration/utils.py:49: PossibleUserWarning: The loaded checkpoint was produced with Lightning v2.0.1.post0, which is newer than your current Lightning version: v2.0.1
#   rank_zero_warn(
# LitEquivariantDDPM(
#   (edm): EquivariantDDPM(
#     (embed_timestep): PositionalEmbedding()
#     (dynamics): EquivariantDynamics(
#       (embed_atom): Embedding(90, 32)
#       (proj_h): Linear(in_features=171, out_features=256, bias=True)
#       (proj_cond): Sequential(
#         (0): Linear(in_features=171, out_features=128, bias=True)
#         (1): Activation()
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): Activation()
#       )
#       (egnn): ModuleList(
#         (0): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (norm_h_agg): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (edge_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#           )
#           (att_mlp): Sequential(
#             (0): Linear(in_features=256, out_features=1, bias=True)
#             (1): Sigmoid()
#           )
#           (node_mlp): Sequential(
#             (0): Linear(in_features=512, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#         (1): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (norm_h_agg): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (edge_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#           )
#           (att_mlp): Sequential(
#             (0): Linear(in_features=256, out_features=1, bias=True)
#             (1): Sigmoid()
#           )
#           (node_mlp): Sequential(
#             (0): Linear(in_features=512, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#         (2): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (norm_h_agg): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (edge_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#           )
#           (att_mlp): Sequential(
#             (0): Linear(in_features=256, out_features=1, bias=True)
#             (1): Sigmoid()
#           )
#           (node_mlp): Sequential(
#             (0): Linear(in_features=512, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#         (3): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (norm_h_agg): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (edge_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#           )
#           (att_mlp): Sequential(
#             (0): Linear(in_features=256, out_features=1, bias=True)
#             (1): Sigmoid()
#           )
#           (node_mlp): Sequential(
#             (0): Linear(in_features=512, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#         (4): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (norm_h_agg): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (edge_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#           )
#           (att_mlp): Sequential(
#             (0): Linear(in_features=256, out_features=1, bias=True)
#             (1): Sigmoid()
#           )
#           (node_mlp): Sequential(
#             (0): Linear(in_features=512, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#         (5): EquivariantBlock(
#           (norm_h): LayerNorm(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#             (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#           )
#           (coord_mlp): Sequential(
#             (0): Linear(in_features=520, out_features=256, bias=True)
#             (1): Activation()
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Activation()
#             (4): Linear(in_features=256, out_features=3, bias=False)
#           )
#         )
#       )
#     )
#     (gamma): NoiseSchedule()
#   )
#   (ema): EMA(
#     (ema_model): EquivariantDDPM(
#       (embed_timestep): PositionalEmbedding()
#       (dynamics): EquivariantDynamics(
#         (embed_atom): Embedding(90, 32)
#         (proj_h): Linear(in_features=171, out_features=256, bias=True)
#         (proj_cond): Sequential(
#           (0): Linear(in_features=171, out_features=128, bias=True)
#           (1): Activation()
#           (2): Linear(in_features=128, out_features=128, bias=True)
#           (3): Activation()
#         )
#         (egnn): ModuleList(
#           (0): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (norm_h_agg): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (edge_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#             )
#             (att_mlp): Sequential(
#               (0): Linear(in_features=256, out_features=1, bias=True)
#               (1): Sigmoid()
#             )
#             (node_mlp): Sequential(
#               (0): Linear(in_features=512, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#           (1): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (norm_h_agg): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (edge_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#             )
#             (att_mlp): Sequential(
#               (0): Linear(in_features=256, out_features=1, bias=True)
#               (1): Sigmoid()
#             )
#             (node_mlp): Sequential(
#               (0): Linear(in_features=512, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#           (2): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (norm_h_agg): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (edge_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#             )
#             (att_mlp): Sequential(
#               (0): Linear(in_features=256, out_features=1, bias=True)
#               (1): Sigmoid()
#             )
#             (node_mlp): Sequential(
#               (0): Linear(in_features=512, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#           (3): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (norm_h_agg): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (edge_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#             )
#             (att_mlp): Sequential(
#               (0): Linear(in_features=256, out_features=1, bias=True)
#               (1): Sigmoid()
#             )
#             (node_mlp): Sequential(
#               (0): Linear(in_features=512, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#           (4): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (norm_h_agg): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (edge_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#             )
#             (att_mlp): Sequential(
#               (0): Linear(in_features=256, out_features=1, bias=True)
#               (1): Sigmoid()
#             )
#             (node_mlp): Sequential(
#               (0): Linear(in_features=512, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#           (5): EquivariantBlock(
#             (norm_h): LayerNorm(
#               (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=False)
#               (proj_ada): Linear(in_features=128, out_features=512, bias=True)
#             )
#             (coord_mlp): Sequential(
#               (0): Linear(in_features=520, out_features=256, bias=True)
#               (1): Activation()
#               (2): Linear(in_features=256, out_features=256, bias=True)
#               (3): Activation()
#               (4): Linear(in_features=256, out_features=3, bias=False)
#             )
#           )
#         )
#       )
#       (gamma): NoiseSchedule()
#     )
#   )
# )

# %%
T = 1000
render_every_n_frames = 1
keep_frames = set(list(reversed(range(-1, T + 1, render_every_n_frames))))
out = model.ema.ema_model.sample(M, keep_frames=keep_frames)
out.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 5
#       3 keep_frames = set(list(reversed(range(-1, T + 1, render_every_n_frames))))
#       4 out = model.ema.ema_model.sample(M, keep_frames=keep_frames)
# ----> 5 out.show()
#
# AttributeError: 'tuple' object has no attribute 'show'

# %%
M_pred, frames = out

# %%
M_pred.show()
# Out:
# <div id="3dmolviewer_16837435366147568"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16837435366147568" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16837435366147568 = null;
# var warn = document.getElementById("3dmolwarning_16837435366147568");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16837435366147568 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16837435366147568"),{backgroundColor:"white"});
# viewer_16837435366147568.zoomTo();
# 	viewer_16837435366147568.addModel("18\n\nC -2.717629 -0.653278 -0.001043\nH -3.773496 -0.414591 0.001748\nH -2.461923 -1.242673 0.892622\nH 2.895004 -1.344597 -0.885775\nO -2.047417 0.585777 0.001204\nC -0.675195 0.503337 0.001363\nC 0.225512 -0.535631 -0.001947\nC 1.526650 0.040599 0.002489\nC 1.352903 1.401762 -0.002372\nN 0.008145 1.668139 0.005554\nH 3.646005 -0.025804 0.003446\nH -0.419410 2.576181 -0.000626\nC 2.812081 -0.713002 -0.001476\nH 2.081742 2.184653 0.000299\nH 0.784342 -2.350720 0.002744\nH -2.454259 -1.243636 -0.891846\nO -0.054020 -1.876775 -0.004193\nH 2.883492 -1.348796 0.883221\n","xyz");
# 	viewer_16837435366147568.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16837435366147568.zoomTo();
# viewer_16837435366147568.render();
# });
# </script>

# %%
from src.metrics import evaluate_prediction

result = evaluate_prediction(M, M_pred)
result
# Out:
# {'unsigned_coords_rmse': 8.346683699755886e-08,
#  'moments_rmse': 0.0,
#  'coord_rmse': 0.03220527246594429,
#  'heavy_coord_rmse': 0.019756125286221504,
#  'transform': tensor([[-1.,  0.,  0.],
#          [ 0., -1.,  0.],
#          [ 0.,  0., -1.]]),
#  'correctness': 1.0}

# %%
M_pred.transform(result['transform'].to('cuda:0')).show()
# Out:
# <div id="3dmolviewer_16837436135347946"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16837436135347946" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16837436135347946 = null;
# var warn = document.getElementById("3dmolwarning_16837436135347946");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16837436135347946 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16837436135347946"),{backgroundColor:"white"});
# viewer_16837436135347946.zoomTo();
# 	viewer_16837436135347946.addModel("18\n\nC 2.715292 -0.662926 0.000566\nH 3.772000 -0.427987 -0.001623\nH 2.457686 -1.249978 -0.894096\nH -2.899951 -1.335723 0.883014\nO 2.049484 0.578503 0.000163\nC 0.676978 0.500938 -0.000415\nC -0.227413 -0.534829 0.001042\nC -1.526496 0.046024 -0.002743\nC -1.347917 1.406552 0.004333\nN -0.002220 1.668164 -0.002884\nH -3.646073 -0.012849 -0.004250\nH 0.428556 2.574671 0.004840\nC -2.814595 -0.703012 -0.000255\nH -2.073970 2.192030 0.002764\nH -0.792684 -2.347912 -0.006673\nH 2.449636 -1.253771 0.890367\nO 0.047354 -1.876959 0.001199\nH -2.888074 -1.337132 -0.885984\n","xyz");
# 	viewer_16837436135347946.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16837436135347946.zoomTo();
# viewer_16837436135347946.render();
# });
# </script>

# %%
M.show()
# Out:
# <div id="3dmolviewer_16837436185235133"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16837436185235133" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16837436185235133 = null;
# var warn = document.getElementById("3dmolwarning_16837436185235133");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16837436185235133 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16837436185235133"),{backgroundColor:"white"});
# viewer_16837436185235133.zoomTo();
# 	viewer_16837436185235133.addModel("18\n\nC 2.719464 -0.656208 0.000734\nH 2.469171 -1.243194 -0.886178\nH 3.781133 -0.415800 -0.000915\nH 2.471256 -1.240146 0.890268\nO 2.043342 0.582218 -0.000553\nC 0.680184 0.501237 -0.000149\nC -0.225850 -0.530600 -0.000160\nC -1.524442 0.047140 0.000102\nC -1.355772 1.405100 0.000272\nN -0.017024 1.672344 -0.000154\nH 0.417812 2.577845 0.001061\nH -2.083865 2.190017 0.000277\nC -2.808300 -0.716633 0.000153\nH -2.887695 -1.349815 0.885554\nH -3.647148 -0.026501 -0.001291\nH -2.886407 -1.352038 -0.883784\nO 0.056852 -1.881886 -0.000358\nH -0.787037 -2.345567 0.000276\n","xyz");
# 	viewer_16837436185235133.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16837436185235133.zoomTo();
# viewer_16837436185235133.render();
# });
# </script>

# %%
M.coords
# Out:
# tensor([[ 2.7195e+00, -6.5621e-01,  7.3354e-04],
#         [ 2.4692e+00, -1.2432e+00, -8.8618e-01],
#         [ 3.7811e+00, -4.1580e-01, -9.1488e-04],
#         [ 2.4713e+00, -1.2401e+00,  8.9027e-01],
#         [ 2.0433e+00,  5.8222e-01, -5.5274e-04],
#         [ 6.8018e-01,  5.0124e-01, -1.4912e-04],
#         [-2.2585e-01, -5.3060e-01, -1.6048e-04],
#         [-1.5244e+00,  4.7140e-02,  1.0193e-04],
#         [-1.3558e+00,  1.4051e+00,  2.7222e-04],
#         [-1.7024e-02,  1.6723e+00, -1.5440e-04],
#         [ 4.1781e-01,  2.5778e+00,  1.0608e-03],
#         [-2.0839e+00,  2.1900e+00,  2.7729e-04],
#         [-2.8083e+00, -7.1663e-01,  1.5328e-04],
#         [-2.8877e+00, -1.3498e+00,  8.8555e-01],
#         [-3.6471e+00, -2.6501e-02, -1.2912e-03],
#         [-2.8864e+00, -1.3520e+00, -8.8378e-01],
#         [ 5.6852e-02, -1.8819e+00, -3.5771e-04],
#         [-7.8704e-01, -2.3456e+00,  2.7596e-04]], device='cuda:0')

# %%
from src.visualize import html_render_trajectory
transform = result['transform'].to('cuda:0') * torch.tensor([1, -1, -1], device='cuda:0')
frames = {step: m.replace(coords=m.coords.to('cpu') @ transform.to('cpu')) for step, m in frames.items()}
frames = [frames[step] for step in list(reversed(range(-1, T + 1, render_every_n_frames))) + [-1]]

# %%
frames[-1].show()
# Out:
# <div id="3dmolviewer_16837442293942168"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16837442293942168" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16837442293942168 = null;
# var warn = document.getElementById("3dmolwarning_16837442293942168");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16837442293942168 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16837442293942168"),{backgroundColor:"white"});
# viewer_16837442293942168.zoomTo();
# 	viewer_16837442293942168.addModel("18\n\nC -2.717629 -0.653278 -0.001043\nH -3.773496 -0.414591 0.001748\nH -2.461923 -1.242673 0.892622\nH 2.895004 -1.344597 -0.885775\nO -2.047417 0.585777 0.001204\nC -0.675195 0.503337 0.001363\nC 0.225512 -0.535631 -0.001947\nC 1.526650 0.040599 0.002489\nC 1.352903 1.401762 -0.002372\nN 0.008145 1.668139 0.005554\nH 3.646005 -0.025804 0.003446\nH -0.419410 2.576181 -0.000626\nC 2.812081 -0.713002 -0.001476\nH 2.081742 2.184653 0.000299\nH 0.784342 -2.350720 0.002744\nH -2.454259 -1.243636 -0.891846\nO -0.054020 -1.876775 -0.004193\nH 2.883492 -1.348796 0.883221\n","xyz");
# 	viewer_16837442293942168.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_16837442293942168.zoomTo();
# viewer_16837442293942168.render();
# });
# </script>

# %%
view2 = py3Dmol.view(width=1500, height=1500)
trajfile = ""
for M in frames:
    trajfile += M.xyzfile()
trajfile = frames[-1].xyzfile() + trajfile  # prepend the last frame so zoomTo works
view2.addModelsAsFrames(trajfile, 'xyz')
view2.setStyle({'sphere':{'scale': 0.5}})
view2.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':arrow_len, 'y':0.0, 'z':0.0},
                      'radius': radius,
                      'color':'red',
                      'mid': mid,
                      })
view2.addArrow({
                      'start': {'x':0.0, 'y':0.0, 'z':0.0},
                      'end': {'x':0.0, 'y':arrow_len, 'z':0.0},
                      'radius': radius,
                      'color':'green',
                        'mid': mid,
                      })
view2.addArrow({
                        'start': {'x':0.0, 'y':0.0, 'z':0.0},
                        'end': {'x':0.0, 'y':0.0, 'z':arrow_len},
                        'radius': radius,
                        'color':'blue',
                        'mid': mid,
                        })
view2.addLabel('x', {'position': {'x':arrow_len, 'y':0.3, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'red', 'fontSize': font_size})
view2.addLabel('y', {'position': {'x':0.6, 'y':arrow_len, 'z':0.0}, 'backgroundOpacity':0.0, 'fontColor':'green', 'fontSize': font_size})  
view2.addLabel('z', {'position': {'x':0.0, 'y':0.15, 'z':arrow_len}, 'backgroundOpacity':0.0, 'fontColor':'blue', 'fontSize': font_size})
view2.rotate(30, {'x': 1, 'y': -1, 'z': -.2})
view2.animate({"loop": "forward", "interval": 10})
view2.zoomTo()
view2.translate(-80, -50)
view2.show()

# %%
view2.render()

t = view2.js()
js = t.startjs + t.endjs
print(js)
# Out:
# <div id="3dmolviewer_UNIQUEID"  style="position: relative; width: 1500px; height: 1500px">
#         <p id="3dmolwarning_UNIQUEID" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_UNIQUEID = null;
# var warn = document.getElementById("3dmolwarning_UNIQUEID");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_UNIQUEID = $3Dmol.createViewer(document.getElementById("3dmolviewer_UNIQUEID"),{backgroundColor:"white"});
# viewer_UNIQUEID.zoomTo();
# 	viewer_UNIQUEID.addModelsAsFrames("18\n\nC -2.717629 -0.653278 -0.001043\nH -3.773496 -0.414591 0.001748\nH -2.461923 -1.242673 0.892622\nH 2.895004 -1.344597 -0.885775\nO -2.047417 0.585777 0.001204\nC -0.675195 0.503337 0.001363\nC 0.225512 -0.535631 -0.001947\nC 1.526650 0.040599 0.002489\nC 1.352903 1.401762 -0.002372\nN 0.008145 1.668139 0.005554\nH 3.646005 -0.025804 0.003446\nH -0.419410 2.576181 -0.000626\nC 2.812081 -0.713002 -0.001476\nH 2.081742 2.184653 0.000299\nH 0.784342 -2.350720 0.002744\nH -2.454259 -1.243636 -0.891846\nO -0.054020 -1.876775 -0.004193\nH 2.883492 -1.348796 0.883221\n18\n\nC -1.458602 -0.073469 0.641875\nH -1.029895 0.100505 -0.567112\nH 1.487512 -1.515991 -3.678176\nH 0.104619 -0.568348 -0.112859\nO -0.835509 -0.356163 -0.914075\nC 0.690934 2.151471 1.118290\nC -0.490483 -0.345453 -0.350839\nC 0.515908 -1.307610 -0.430522\nC -0.159288 -0.002726 0.842819\nN 0.410456 -0.462447 0.723639\nH 0.801258 -0.932847 0.590785\nH -0.236986 0.298080 -0.315574\nC -0.333126 0.560132 -1.275001\nH 1.826313 0.649700 -2.198710\nH 0.866491 0.340965 1.603518\nH 1.939880 -0.701354 -0.096825\nO 1.042162 0.138561 0.198422\nH -0.041086 0.511591 -0.430130\n18\n\nC -1.576381 0.227311 0.750238\nH -1.321543 -0.345965 -0.146495\nH 0.946462 -1.018440 -3.455400\nH 0.263526 -0.785106 -0.224671\nO -0.331684 0.093979 -0.668788\nC 0.641372 1.470366 1.478585\nC -0.483445 -1.125487 -0.409415\nC 0.402740 -0.967057 0.142851\nC -0.854287 0.426045 0.891303\nN 0.218280 -0.390599 -0.037948\nH 0.547582 -0.293738 0.973087\nH 0.412839 -0.153296 -0.156975\nC 0.017686 1.432738 -1.731350\nH 2.150761 0.130519 -1.760633\nH 0.607256 1.276394 2.503471\nH 1.814287 -0.875000 0.538709\nO 1.270267 -0.742746 -0.013370\nH -1.294826 0.357560 -0.279482\n18\n\nC -1.517051 1.646855 -0.079945\nH -0.630444 -0.412680 -1.580054\nH 0.101260 -1.200460 -3.731943\nH 0.061901 -0.526350 -0.207060\nO 0.022421 -0.011920 0.071437\nC 0.116163 -0.146668 0.002745\nC 0.534483 -0.557043 -0.092310\nC -0.126207 -1.525521 0.215856\nC 0.172822 -0.390437 0.995473\nN -0.394046 0.661306 0.546709\nH -0.800140 0.007958 1.844767\nH -0.911215 -0.874014 -0.692127\nC -0.035750 2.497986 -1.359889\nH 1.308481 0.429997 -0.145295\nH 1.122814 0.574377 1.767011\nH 2.077636 0.052784 -0.083100\nO 0.896214 -1.610583 -0.094972\nH -1.247901 0.350332 -0.607646\n18\n\nC -0.021556 1.094497 1.247723\nH -0.080094 -0.063693 -0.903828\nH 0.808264 -0.357765 -1.396675\nH -0.511111 -0.916237 0.535457\nO -0.141914 -0.199981 0.346231\nC -0.001955 -0.016360 0.700377\nC 0.513351 0.350792 -0.424265\nC 0.481197 -1.429501 -0.282141\nC -0.089223 0.401329 -0.014785\nN -1.224627 -0.347183 0.883400\nH -0.475156 -0.061172 1.727776\nH -1.431010 -1.133538 0.349966\nC -0.101921 1.553801 -1.422925\nH 1.229321 1.788152 -0.186267\nH 0.580810 0.756080 1.006861\nH 1.820600 0.050295 0.306054\nO 0.613022 -1.001866 -0.988735\nH -1.689116 0.563366 -1.182677\n18\n\nC -1.119553 0.099554 1.348541\nH -0.177118 -0.023749 -0.046296\nH 0.968710 -0.544680 -1.749977\nH -0.434384 -1.181483 0.458543\nO 0.121661 0.331917 -0.244585\nC 0.651905 0.604660 1.406878\nC 0.726321 0.653467 0.076775\nC 0.977746 -1.775217 -0.621774\nC 0.424219 0.627694 1.084536\nN -2.298351 -0.146738 0.922555\nH 0.132392 -0.948384 1.790030\nH -0.699574 -0.710981 0.048165\nC -0.088064 -0.036858 -2.063444\nH 0.849522 2.063592 -0.588872\nH 0.589036 0.789864 0.407224\nH 1.614882 -0.366286 0.116171\nO 0.628440 -0.322806 -1.434685\nH -1.538386 0.752884 -1.265472\n18\n\nC -0.387639 0.100135 1.095835\nH 0.191882 -0.086286 -0.297233\nH 0.839942 -1.302590 -2.160207\nH -0.023045 -1.466140 0.179708\nO -0.954620 0.025591 0.044236\nC -0.085620 0.308240 1.049056\nC 1.745119 0.933027 -0.297197\nC 1.226537 -1.416972 -1.114148\nC 0.107441 1.026596 1.408514\nN -1.011914 0.642967 0.980670\nH -0.957909 -0.384266 0.926763\nH 0.071224 0.084689 -0.050941\nC -0.572966 -0.137295 -0.726632\nH 0.405574 1.964873 -0.238858\nH -0.105173 0.836897 -0.399716\nH 1.934453 -0.534330 -0.508257\nO 0.251086  ...
# 	viewer_UNIQUEID.setStyle({"sphere": {"scale": 0.5}});
# 	viewer_UNIQUEID.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 6.5, "y": 0.0, "z": 0.0}, "radius": 0.25, "color": "red", "mid": 0.9});
# 	viewer_UNIQUEID.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 6.5, "z": 0.0}, "radius": 0.25, "color": "green", "mid": 0.9});
# 	viewer_UNIQUEID.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 6.5}, "radius": 0.25, "color": "blue", "mid": 0.9});
# 	viewer_UNIQUEID.addLabel("x",{"position": {"x": 6.5, "y": 0.3, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "red", "fontSize": 80});
# 	viewer_UNIQUEID.addLabel("y",{"position": {"x": 0.6, "y": 6.5, "z": 0.0}, "backgroundOpacity": 0.0, "fontColor": "green", "fontSize": 80});
# 	viewer_UNIQUEID.addLabel("z",{"position": {"x": 0.0, "y": 0.15, "z": 6.5}, "backgroundOpacity": 0.0, "fontColor": "blue", "fontSize": 80});
# 	viewer_UNIQUEID.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_UNIQUEID.animate({"loop": "forward", "interval": 10});
# 	viewer_UNIQUEID.zoomTo();
# 	viewer_UNIQUEID.translate(-80,-50);
# 	viewer_UNIQUEID.render();
# 	viewer_UNIQUEID.js();
# viewer_UNIQUEID.render();
# });
# </script>
