# %%
# import msgpack

# %%
# import os

# # change to where your data is located
# direc = "/scratch/auhcheng/geom-data"

# drugs_file = os.path.join(direc, "drugs_crude.msgpack")
# unpacker = msgpack.Unpacker(open(drugs_file, "rb"))

# %%
# drugs_1k = next(iter(unpacker))

# %%
# import pickle
# with open('drugs_1k.pkl', 'wb') as f:
#     pickle.dump(drugs_1k, f)

# %%
import pickle
with open('drugs_1k.pkl', 'rb') as f:
    drugs_1k = pickle.load(f)

# %%
drugs_1k[list(drugs_1k.keys())[0]]
# Out:
# {'conformers': [{'xyz': [[6.0, -5.1394449278, -1.4232879102, -0.3562914678],
#     [6.0, -4.3420257656, -1.3874200395, -1.4064768697],
#     [6.0, -2.9313415662, -0.8706753753, -1.4188560961],
#     [7.0, -2.4599320079, -0.4490760698, -0.1317277828],
#     [6.0, -2.2562842288, 0.8243789295, 0.296297872],
#     [7.0, -1.7743140969, 0.8285799112, 1.5148836705],
#     [7.0, -1.6397056668, -0.4505887964, 1.8992369618],
#     [6.0, -2.0341045588, -1.2161059062, 0.9219426163],
#     [6.0, -2.0440617795, -2.687053635, 0.9245527666],
#     [1.0, -2.6967264243, -3.0777696386, 0.1452546068],
#     [1.0, -2.3567636788, -3.0601275315, 1.8992157072],
#     [16.0, -0.383127371, -3.4698331239, 0.6916313527],
#     [6.0, 0.5220126773, -2.3219437472, -0.2294736407],
#     [7.0, 0.1069793333, -1.180354721, -0.6293663327],
#     [6.0, 1.0924580091, -0.4693468275, -1.2541640322],
#     [6.0, 0.966616544, 0.8222711775, -1.7518444682],
#     [6.0, 2.0699420813, 1.4251493884, -2.3178505337],
# ...
